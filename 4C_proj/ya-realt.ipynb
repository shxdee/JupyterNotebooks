# %%
import time
from datetime import datetime
import requests
import csv
import json

# %%
def get_json():
    cookies = {
        'yandex_login': 'shadixddd@gmail.com',
        'i': 'U3BcqS4RXCCqfNHtB6Db2pwSZyv/P7FLWMt2wk09P9g5OntyLJuiSRa7z/IUsX+karK2rmtgMV2uUn4/7hDkgFmFVmU=',
        'yandexuid': '5143712471688644541',
        'L': 'YjVaVlZZREt7elNVdVpxe35iVnhWXXtWATE3VCQtEzAeLBdcNgYlfiEKKA==.1692722952.15442.339866.c4c70bbe54e33e59d3ff08aa632d61e6',
        'suid': '8995cc3f3fb4eb0d55fb2ba274183c7e.75cde346e9bc329465546cb92a041a7e',
        '_csrf_token': '376568cbd45ddbc66d1d04d246be946f1b5300f6709aa107',
        'exp_uid': 'e823a342-d51f-4b7a-ab80-63e6bd4ba99c',
        'Session_id': '3:1697102601.5.0.1692722952824:INnpLg:51.1.2:1|1342694298.-1.0.3:1692722952|6:10185586.871026.pmp6blnJNkydMS8cOLXBQQK0pGU',
        'sessar': '1.1182.CiCwI1Aaa3t5xnGgoqEKIpVIBhx0cOQMTX3plXErdxjfLg.onTfwIjrmyGa7MTA2Ma1jklDI14MW4vQqMIYDxBFbSM',
        'yp': '1691322943.hdrc.0#1689249343.mcl.#1689249343.mcv.0#1720180543.p_sw.1688644542#2004004543.pcs.1#1689249343.szm.1:1920x1080:1910x933#2012462601.udn.cDpzaGFkaXhkZGRAZ21haWwuY29t',
        'ys': 'udn.cDpzaGFkaXhkZGRAZ21haWwuY29t#c_chck.3267843793',
        'mda2_beacon': '1697102601738',
        'sso_status': 'sso.passport.yandex.ru:synchronized',
        'from': '',
        'show_egrn_reports_link': 'NO_1342694298',
        'font_loaded': 'YSv1',
        'gdpr': '0',
        '_ym_uid': '1697102673108933705',
        '_ym_d': '1697102673',
        '_ym_isad': '1',
        'link_to_global_tooltip_shown': 'YES',
        'prev_uaas_data': '%7B%22uaasUid%22%3A%225143712471688644541%22%2C%22uaasExpNames%22%3A%5B%22REALTYFRONT-16375_cashback_from_yandex_plus_in_card%22%2C%22REALTYFRONT-16113_bring_tenant_banner%22%2C%22REALTYFRONT-16792_show_arenda_chat_button%22%2C%22REALTYFRONT-17599_new_owner_target%22%2C%22REALTYFRONT-16960-mortgage-calc-on-cards%22%2C%22REALTYFRONT-18136_disable-all-popups%22%2C%22REALTYFRONT-18038_tenant_search_bar%22%2C%22REALTYFRONT-17031_site_rating%22%2C%22REALTYBACK-9999_disable_paid_only%22%2C%22REALTYFRONT-18965_fast_link_random_position%22%2C%22REALTYFRONT-18486_hide_candidates_questionnaire%22%2C%22REALTYFRONT-17115_referral_with_stories%22%2C%22arenda-aa-exp%22%2C%22REALTYFRONT-17334_group_3%22%5D%7D',
        'prev_uaas_expcrypted': 'o3Ff-gDb4c-YaWl6wA_TFcy26RRrPHeQ9NQJCv_sMk5JiIzMr3g0jZSkvnj1hR7Wc3nxhQxK4cN4UDZsTu9v0t3Th--_jGDm3JGpW-fFBn1lI1wtM2iaEfFCcdFPtP_P055Avm0SqcdfTet4UT_D7zC8jbYqTDCYrYcE5FnyVG7OGGdbn6t-L7MMyENoq8t7vOLGHMjSiY-eXMtOeaLm-Ht3jpN_jhHkeBk0rrwf_Jn9WFhxh3eF49d9J9_Dk66jKf8tQ1YI7zXDlFMH-msC8G51ezzNrAEy',
        cookies=cookies,
        headers=headers)
    
    data = response.json()

    return data

# %%
   def get_json(): 
    cookies = {
        'suid': 'b4257983132ef839675ff6a86dcbcc70.062755b5a730c01d0f3b4adc476d29cc',
        '_csrf_token': '87ccfb6d89c86e1e990da3954e6a42da3efd2109eba56081',
        'yandexuid': '2201022671697115325',
        'Cookie_check': 'checked',
        'from': '',
        'exp_uid': 'd0b9e0d5-f061-4c2a-a4f7-1425c8fb69b7',
        'rgid': '552970',
        'geo_id': '66',
        'region_id': '11318',
        '_yasc': 'C61+iW2R6x+uqCHLzsmdRjeP9r1tB1jy5V5MxdUH/deLsl48ByxraA1lFHKZhJ7AtA==',
        'font_loaded': 'YSv1',
        'prev_uaas_data': '%7B%22uaasUid%22%3A%222201022671697115325%22%2C%22uaasExpNames%22%3A%5B%22REALTYFRONT-16375_cashback_from_yandex_plus_in_card%22%2C%22REALTYFRONT-16113_bring_tenant_banner%22%2C%22REALTYFRONT-16792_show_arenda_chat_button%22%2C%22REALTYFRONT-17599_new_owner_target%22%2C%22REALTYFRONT-16960-mortgage-calc-on-cards%22%2C%22REALTYFRONT-18136_disable-all-popups%22%2C%22REALTYFRONT-18038_tenant_search_bar%22%2C%22REALTYFRONT-17031_site_rating%22%2C%22REALTYBACK-9999_disable_paid_only%22%2C%22REALTYFRONT-18965_fast_link_random_position%22%2C%22REALTYFRONT-18989_fs_gallery_dark%22%2C%22REALTYFRONT-18683_arenda_promo_on_site_cards%22%2C%22realty_aa_experiment%22%2C%22arenda-aa-exp%22%2C%22REALTYFRONT-17334_group_3%22%5D%7D',
        'prev_uaas_expcrypted': 'o3Ff-gDb4c8rIELSL6SHjyt13AgQdUyi5Pg2J4smvz7GSVe2FQwwIf0wNPyMGiXpX8_8r-QJdbipi-xL9rpGJLmVYdcrFyFT4V2ENBmJH5JE9K7BLkCeHAF6IABbvCDbvCr28pj18RKt4PJ-HEwQTu-rhaEfbm8tEkAYyoYq0Q9jGaaUxHUPH9PUlxn0G1A3',
        'from_lifetime': '1697115328230',
        'gdpr': '0',
        '_ym_uid': '1697115395996611275',
        '_ym_d': '1697115396',
    }

    headers = {
        'authority': 'realty.ya.ru',
        'accept': 'application/json',
        'accept-language': 'en-US,en;q=0.9',
        'client-view-type': 'desktop',
        'content-type': 'application/json',
        # 'cookie': 'suid=b4257983132ef839675ff6a86dcbcc70.062755b5a730c01d0f3b4adc476d29cc; _csrf_token=87ccfb6d89c86e1e990da3954e6a42da3efd2109eba56081; yandexuid=2201022671697115325; Cookie_check=checked; from=; exp_uid=d0b9e0d5-f061-4c2a-a4f7-1425c8fb69b7; rgid=552970; geo_id=66; region_id=11318; _yasc=C61+iW2R6x+uqCHLzsmdRjeP9r1tB1jy5V5MxdUH/deLsl48ByxraA1lFHKZhJ7AtA==; font_loaded=YSv1; prev_uaas_data=%7B%22uaasUid%22%3A%222201022671697115325%22%2C%22uaasExpNames%22%3A%5B%22REALTYFRONT-16375_cashback_from_yandex_plus_in_card%22%2C%22REALTYFRONT-16113_bring_tenant_banner%22%2C%22REALTYFRONT-16792_show_arenda_chat_button%22%2C%22REALTYFRONT-17599_new_owner_target%22%2C%22REALTYFRONT-16960-mortgage-calc-on-cards%22%2C%22REALTYFRONT-18136_disable-all-popups%22%2C%22REALTYFRONT-18038_tenant_search_bar%22%2C%22REALTYFRONT-17031_site_rating%22%2C%22REALTYBACK-9999_disable_paid_only%22%2C%22REALTYFRONT-18965_fast_link_random_position%22%2C%22REALTYFRONT-18989_fs_gallery_dark%22%2C%22REALTYFRONT-18683_arenda_promo_on_site_cards%22%2C%22realty_aa_experiment%22%2C%22arenda-aa-exp%22%2C%22REALTYFRONT-17334_group_3%22%5D%7D; prev_uaas_expcrypted=o3Ff-gDb4c8rIELSL6SHjyt13AgQdUyi5Pg2J4smvz7GSVe2FQwwIf0wNPyMGiXpX8_8r-QJdbipi-xL9rpGJLmVYdcrFyFT4V2ENBmJH5JE9K7BLkCeHAF6IABbvCDbvCr28pj18RKt4PJ-HEwQTu-rhaEfbm8tEkAYyoYq0Q9jGaaUxHUPH9PUlxn0G1A3; from_lifetime=1697115328230; gdpr=0; _ym_uid=1697115395996611275; _ym_d=1697115396',
        'dnt': '1',
        'origin': 'https://realty.ya.ru',
        'referer': 'https://realty.ya.ru/omsk/kupit/kvartira/',
        'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Google Chrome";v="116"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
        'x-client-version': '468.0.12650692',
        'x-metrika-client-id': '1697115395996611275',
        'x-requested-with': 'XMLHttpRequest',
        'x-retpath-y': 'https://realty.ya.ru/omsk/kupit/kvartira/',
    }

    params = {
        'crc': 'ycb655f802f5a1370482e6c39ba67122a',
    }

    json_data = {
        'params': [
            [
                'show',
                {
                    'card_type': 'newbuilding',
                    'method': 'stat.offer',
                    'newLog': {
                        'objectInfo': {
                            'location': {
                                'rgid': 176912,
                                'subjectFederationId': 11318,
                            },
                            'shownInfo': {
                                'mainPhotoUrl': '//avatars.mds.yandex.net/get-verba/1030388/2a0000017609aaf8b078514e14dc32db6498/realty_main',
                                'siteShownInfo': {
                                    'badgeShown': [],
                                    'siteStatistics': [
                                        {
                                            'areaFrom': 36.4,
                                            'priceFrom': 5275100,
                                            'priceStatus': 1,
                                            'rooms': 1,
                                        },
                                        {
                                            'areaFrom': 59.8,
                                            'priceFrom': 7896240,
                                            'priceStatus': 1,
                                            'rooms': 2,
                                        },
                                        {
                                            'areaFrom': 76.1,
                                            'priceFrom': 9890400,
                                            'priceStatus': 1,
                                            'rooms': 3,
                                        },
                                        {
                                            'priceStatus': 0,
                                            'rooms': 5,
                                        },
                                        {
                                            'priceStatus': 0,
                                            'rooms': 4,
                                        },
                                    ],
                                },
                            },
                            'siteInfo': {
                                'developerId': [
                                    '2431162',
                                ],
                                'paid': False,
                                'superCall': False,
                                'uniquePromotion': False,
                            },
                        },
                        'requestContext': {
                            'cardViewType': 'newbuilding',
                            'eventPlace': 'listing_newbuilding_recommendations',
                            'queryInfo': {
                                'queryId': '986a041c7a5f857566cb5bed5dfe2853',
                                'queryText': '/omsk/kupit/kvartira/',
                            },
                        },
                        'trafficSource': {},
                        'payload': {},
                    },
                    'offer_category': 'APARTMENT',
                    'offer_from': 'newbuilding',
                    'offer_id': 'site:2431251',
                    'offer_position': 3,
                    'offer_traffic_from': 'direct',
                    'offer_type': 'SELL',
                    'offer_url': '/omsk/kupit/novostrojka/enisejskij-2431251/',
                    'page_index': 0,
                    'query_id': '986a041c7a5f857566cb5bed5dfe2853',
                    'site_id': 2431251,
                    'currentUrl': 'https://realty.ya.ru/omsk/kupit/kvartira/',
                },
            ],
            [
                'show',
                {
                    'card_type': 'newbuilding',
                    'method': 'stat.offer',
                    'newLog': {
                        'objectInfo': {
                            'location': {
                                'rgid': 176908,
                                'subjectFederationId': 11318,
                            },
                            'shownInfo': {
                                'mainPhotoUrl': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017629043198225722ff48b834dd4c/realty_main',
                                'siteShownInfo': {
                                    'badgeShown': [
                                        'discount',
                                    ],
                                    'badgeText': 'Скидка 3%',
                                    'siteStatistics': [
                                        {
                                            'priceStatus': 0,
                                            'rooms': 1,
                                        },
                                        {
                                            'areaFrom': 77,
                                            'priceFrom': 10216800,
                                            'priceStatus': 1,
                                            'rooms': 2,
                                        },
                                        {
                                            'areaFrom': 104,
                                            'priceFrom': 13701600,
                                            'priceStatus': 1,
                                            'rooms': 3,
                                        },
                                        {
                                            'priceStatus': 0,
                                            'rooms': 5,
                                        },
                                        {
                                            'priceStatus': 0,
                                            'rooms': 4,
                                        },
                                    ],
                                },
                            },
                            'siteInfo': {
                                'developerId': [
                                    '2438122',
                                ],
                                'paid': False,
                                'superCall': False,
                                'uniquePromotion': False,
                            },
                        },
                        'requestContext': {
                            'cardViewType': 'newbuilding',
                            'eventPlace': 'listing_newbuilding_recommendations',
                            'queryInfo': {
                                'queryId': '986a041c7a5f857566cb5bed5dfe2853',
                                'queryText': '/omsk/kupit/kvartira/',
                            },
                        },
                        'trafficSource': {},
                        'payload': {},
                    },
                    'offer_category': 'APARTMENT',
                    'offer_from': 'newbuilding',
                    'offer_id': 'site:2437018',
                    'offer_position': 2,
                    'offer_traffic_from': 'direct',
                    'offer_type': 'SELL',
                    'offer_url': '/omsk/kupit/novostrojka/ehkopark-2437018/',
                    'page_index': 0,
                    'query_id': '986a041c7a5f857566cb5bed5dfe2853',
                    'site_id': 2437018,
                    'currentUrl': 'https://realty.ya.ru/omsk/kupit/kvartira/',
                },
            ],
            [
                'show',
                {
                    'card_type': 'newbuilding',
                    'method': 'stat.offer',
                    'newLog': {
                        'objectInfo': {
                            'location': {
                                'rgid': 176912,
                                'subjectFederationId': 11318,
                            },
                            'shownInfo': {
                                'mainPhotoUrl': '//avatars.mds.yandex.net/get-verba/216201/2a0000018408f9b75e001dd452148a928be0/realty_main',
                                'siteShownInfo': {
                                    'badgeShown': [
                                        'sale',
                                        'installment',
                                    ],
                                    'siteStatistics': [
                                        {
                                            'areaFrom': 48.8,
                                            'priceFrom': 6400000,
                                            'priceStatus': 1,
                                            'rooms': 1,
                                        },
                                        {
                                            'areaFrom': 62.7,
                                            'priceFrom': 8262000,
                                            'priceStatus': 1,
                                            'rooms': 2,
                                        },
                                        {
                                            'areaFrom': 81.6,
                                            'priceFrom': 10900000,
                                            'priceStatus': 1,
                                            'rooms': 3,
                                        },
                                        {
                                            'priceStatus': 0,
                                            'rooms': 5,
                                        },
                                        {
                                            'priceStatus': 0,
                                            'rooms': 4,
                                        },
                                    ],
                                },
                            },
                            'siteInfo': {
                                'developerId': [
                                    '285658',
                                ],
                                'paid': False,
                                'superCall': False,
                                'uniquePromotion': False,
                            },
                        },
                        'requestContext': {
                            'cardViewType': 'newbuilding',
                            'eventPlace': 'listing_newbuilding_recommendations',
                            'queryInfo': {
                                'queryId': '986a041c7a5f857566cb5bed5dfe2853',
                                'queryText': '/omsk/kupit/kvartira/',
                            },
                        },
                        'trafficSource': {},
                        'payload': {
                            'key': '...',
                        },
                    },
                    'offer_category': 'APARTMENT',
                    'offer_from': 'newbuilding',
                    'offer_id': 'site:3142451',
                    'offer_position': 1,
                    'offer_traffic_from': 'direct',
                    'offer_type': 'SELL',
                    'offer_url': '/omsk/kupit/novostrojka/kvartaly-draverta-3142451/',
                    'page_index': 0,
                    'query_id': '986a041c7a5f857566cb5bed5dfe2853',
                    'site_id': 3142451,
                    'currentUrl': 'https://realty.ya.ru/omsk/kupit/kvartira/',
                },
            ],
            [
                'show',
                {
                    'offer_id': '5227592106632815140',
                    'offer_url': '/offer/5227592106632815140/',
                    'offer_category': 'APARTMENT',
                    'offer_type': 'SELL',
                    'offer_unit': '30.4',
                    'offer_from': 'search',
                    'card_type': 'used',
                    'offer_position': '1',
                    'offer_partner_id': '1069342742',
                    'offer_author_uid': '1843058106',
                    'subject_federation_id': '552970',
                    'query_id': '986a041c7a5f857566cb5bed5dfe2853',
                    'page_index': '0',
                    'serp_type': 'offers',
                    'flat_type': 'SECONDARY',
                    'primary_sale': 'false',
                    'offer_services': 'premium,raising,xml-raising',
                    'newLog': {
                        'objectInfo': {
                            'location': {
                                'rgid': 176912,
                                'subjectFederationId': 11318,
                            },
                            'offerInfo': {
                                'authorInfo': {
                                    'category': 'AGENCY',
                                    'uid': '1843058106',
                                },
                                'apartmentInfo': {
                                    'flatType': 'SECONDARY',
                                    'roomsOffered': 1,
                                    'roomsTotal': 1,
                                    'studio': False,
                                    'totalArea': 30.4,
                                },
                                'isWithWhatsApp': False,
                                'offerCategoryField': 'APARTMENT',
                                'offerId': '5227592106632815140',
                                'offerTypeField': 'SELL',
                                'phoneInfo': {
                                    'phone': {},
                                },
                                'revoked': False,
                                'sellOffer': {
                                    'price': {
                                        'currency': 'RUB',
                                        'value': 3000000,
                                    },
                                    'primarySale': False,
                                },
                            },
                            'payload': {},
                            'shownInfo': {
                                'mainPhotoUrl': '//avatars.mds.yandex.net/get-realty/4794678/offer.5227592106632815140.3367374691414067723/main',
                                'updateTime': 1697104800000,
                                'offerShownInfo': {
                                    'badgeShown': [],
                                },
                            },
                        },
                        'requestContext': {
                            'cardViewType': 'used',
                            'eventPlace': 'listing',
                            'queryInfo': {
                                'queryId': '986a041c7a5f857566cb5bed5dfe2853',
                                'queryText': '/omsk/kupit/kvartira/',
                            },
                        },
                        'trafficSource': {},
                        'userInfo': {
                            'webUserInfo': {},
                        },
                    },
                    'currentUrl': 'https://realty.ya.ru/omsk/kupit/kvartira/',
                },
            ],
            [
                'show',
                {
                    'card_type': 'newbuilding',
                    'method': 'stat.offer',
                    'newLog': {
                        'objectInfo': {
                            'location': {
                                'rgid': 176912,
                                'subjectFederationId': 11318,
                            },
                            'shownInfo': {
                                'mainPhotoUrl': '//avatars.mds.yandex.net/get-verba/1604130/2a000001849f42e0f2361bd0189b9b415783/realty_main',
                                'siteShownInfo': {
                                    'badgeShown': [
                                        'mortgage',
                                        'mortgage',
                                        'mortgage',
                                    ],
                                    'badgeText': 'Ипотека с господдержкой от 0.01%',
                                    'siteStatistics': [
                                        {
                                            'areaFrom': 33.7,
                                            'priceFrom': 4177772,
                                            'priceStatus': 1,
                                            'rooms': 1,
                                        },
                                        {
                                            'areaFrom': 50.9,
                                            'priceFrom': 5727874,
                                            'priceStatus': 1,
                                            'rooms': 2,
                                        },
                                        {
                                            'areaFrom': 73.9,
                                            'priceFrom': 7530229,
                                            'priceStatus': 1,
                                            'rooms': 3,
                                        },
                                        {
                                            'areaFrom': 25.7,
                                            'priceFrom': 3511560,
                                            'priceStatus': 1,
                                            'rooms': 5,
                                        },
                                        {
                                            'areaFrom': 96.3,
                                            'priceFrom': 10506498,
                                            'priceStatus': 1,
                                            'rooms': 4,
                                        },
                                    ],
                                },
                            },
                            'siteInfo': {
                                'developerId': [
                                    '23900',
                                ],
                                'paid': False,
                                'superCall': False,
                                'uniquePromotion': False,
                            },
                        },
                        'requestContext': {
                            'cardViewType': 'newbuilding',
                            'eventPlace': 'listing_newbuilding_recommendations',
                            'queryInfo': {
                                'queryId': '986a041c7a5f857566cb5bed5dfe2853',
                                'queryText': '/omsk/kupit/kvartira/',
                            },
                        },
                        'trafficSource': {},
                        'payload': {
                            'key': '...',
                        },
                    },
                    'offer_category': 'APARTMENT',
                    'offer_from': 'newbuilding',
                    'offer_id': 'site:2897082',
                    'offer_position': 0,
                    'offer_traffic_from': 'direct',
                    'offer_type': 'SELL',
                    'offer_url': '/omsk/kupit/novostrojka/zelenaya-reka-2897082/',
                    'page_index': 0,
                    'query_id': '986a041c7a5f857566cb5bed5dfe2853',
                    'site_id': 2897082,
                    'currentUrl': 'https://realty.ya.ru/omsk/kupit/kvartira/',
                },
            ],
        ],
    }

    response = requests.post('https://realty.yandex.ru/gate/react-page/get/', params=params, cookies=cookies, headers=headers, json=json_data)
    
    # https://realty.ya.ru/gate/stat/offer/
    
    data = response.json()
    
    with open("response.json", "w", encoding="utf-8") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

    return data

# %%
def get_json():
    params = (
        ('sort', 'DATE_DESC'),
        ('rgid', '741964'),
        ('type', 'RENT'),
        ('category', 'APARTMENT'),
        ('agents', 'NO'),
        ('_pageType', 'search'),
        ('_providers',
         ['seo', 'queryId', 'forms', 'filters', 'filtersParams', 'direct', 'mapsPromo', 'newbuildingPromo',
          'refinements', 'search', 'react-search-data', 'searchHistoryParams', 'searchParams', 'searchPresets',
          'serpDirectPicType', 'showSurveyBanner', 'seo-data-offers-count', 'related-newbuildings', 'breadcrumbs',
          'ads', 'categoryTotalOffers', 'footer-links', 'site-special-projects']),
        ('crc', 'u4f6278deddd331b5068e5d14a357bfb2'),
    )

    response = requests.get('https://realty.yandex.ru/gate/react-page/get/', params=params)
    data = response.json()
    
    with open("response.json", "w", encoding="utf-8") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

    return data

# %%
def get_json():
    params = (
        ('sort', 'DATE_DESC'),
        ('rgid', '741964'),
        ('type', 'RENT'),
        ('category', 'APARTMENT'),
        ('agents', 'NO'),
        ('_pageType', 'search'),
        ('_providers',
         ['seo', 'queryId', 'forms', 'filters', 'filtersParams', 'direct', 'mapsPromo', 'newbuildingPromo',
          'refinements', 'search', 'react-search-data', 'searchHistoryParams', 'searchParams', 'searchPresets',
          'serpDirectPicType', 'showSurveyBanner', 'seo-data-offers-count', 'related-newbuildings', 'breadcrumbs',
          'ads', 'categoryTotalOffers', 'footer-links', 'site-special-projects']),
        ('crc', 'u4f6278deddd331b5068e5d14a357bfb2'),
    )

    response = requests.get('https://realty.yandex.ru/gate/react-page/get/', params=params)
    data = response.json()
    
    with open("response.json", "w", encoding="utf-8") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

    return data

# %%
def get_offer(item):
    offer = {}

    offer["url"] = item["shareUrl"]
    offer["offer_id"] = item["offerId"]

    offer_date = ''
    if item.get("updateDate"):
        offer_date = item["updateDate"].replace('T', ' ').replace('Z', '')
    else:
        offer_date = item["creationDate"].replace('T', ' ').replace('Z', '')
    offer["date"] = offer_date

    offer["price"] = item["price"]["value"]
    offer["address"] = item["location"]["address"]
    offer["area"] = item["area"]["value"]
    offer["rooms"] = item["roomsTotalKey"]
    offer["floor"] = item["floorsOffered"][0]
    offer["floors_total"] = item["floorsTotal"]

    return offer

# %%
def get_offers(data):
    with open("ya_flats.csv", "w", encoding="utf-8") as file:
        writer = csv.writer(file)
    entities = data["response"]["search"]["offers"]["entities"]
    for item in entities:
        offer = get_offer(item)
        writer.writerow(
            (
                offer["url"],
                offer["id"],
                offer["date"],
                offer["price"],
                offer["address"],
                offer["area"],
                offer["rooms"],
                offer["floor"],
                offer["floors_total"]
            )
        )
        # break

# %%
def main():
    with open("ya_flats.csv", "w", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(
            (
                "url",
                "id",
                "date",
                "price",
                "address",
                "area",
                "rooms",
                "floor",
                "floors_total"
            )
        )
    
    data = get_json()
    get_offers(data)


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import requests
import csv
from bs4 import BeautifulSoup

# URL of the webpage
#url = "https://realty.ya.ru/omsk/kupit/kvartira/?ctype=SELL"

# Send a GET request to the webpage
#response = requests.get(url)

# Parse the HTML content
#soup = BeautifulSoup(response.content, "html.parser")

# Find all the flat listings on the page
flat_listings = soup.find_all('div[class*="Item__info"]')      #find_all("div", class_*="Item__info")
print(flat_listings)

# Create a CSV file to store the data
csv_file = open("flats_data.csv", "w", newline="")
csv_writer = csv.writer(csv_file)
    
# Write the header row in the CSV file
csv_writer.writerow(["Title", "Price", "Floors", "Location"])

# Iterate over each flat listing and extract the relevant information
for listing in flat_listings:
    title = listing.find('span[class*="Item__title"]').text.strip()  #find("span", class_*="Item__title").text.strip()
    price = listing.find('span[class*="price"]').text.strip()  #find("span", class_*="price").text.strip()
    floor = listing.find('span[class*="Item__building"]').text.strip()  #find("span", class_*="Item__building").text.strip()
    location = listing.find('span[class*="Item__address"]').text.strip()  #find("span", class_*="Item__address").text.strip()
    
    # Write the data row in the CSV file
    csv_writer.writerow([title, price, floor, location])

# Close the CSV file
csv_file.close()

print("Data extracted and saved to flats_data.csv")
# Out:
# []
# Data extracted and saved to flats_data.csv
